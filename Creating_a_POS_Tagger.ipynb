# %% [markdown]
# <a href="https://colab.research.google.com/github/NavedAFZ/NLP/blob/master/Creating_a_POS_Tagger.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import nltk
nltk.download('brown')
# Out:
# [nltk_data] Downloading package brown to /root/nltk_data...
# [nltk_data]   Unzipping corpora/brown.zip.
# True

# %% [markdown]
# #Creating a POS Tagger
# We can train a classifier to work out which suffixes are most informative for POS tagging. We can begin by finding out what the most common suffixes are

# %%
from nltk.corpus import brown
from nltk import FreqDist

suffix_fdist = FreqDist()
for word in brown.words():
    
    word = word.lower()
    suffix_fdist[word[-1:]] += 1
    suffix_fdist[word[-2:]] += 1
    suffix_fdist[word[-3:]] += 1
    
suffix_fdist
# Out:
# FreqDist({'e': 202946,
#           'he': 92084,
#           'the': 70026,
#           'n': 87889,
#           'on': 33382,
#           'ton': 1019,
#           'y': 59146,
#           'ty': 6458,
#           'nty': 391,
#           'd': 105687,
#           'nd': 36418,
#           'and': 31057,
#           'ry': 7500,
#           'ury': 482,
#           'id': 4272,
#           'aid': 2460,
#           'ay': 6482,
#           'day': 1613,
#           'an': 17650,
#           'ion': 14905,
#           'f': 43173,
#           'of': 72978,
#           's': 128722,
#           "'s": 5865,
#           "a's": 202,
#           't': 94459,
#           'nt': 13151,
#           'ent': 9369,
#           'ary': 2122,
#           'ed': 41527,
#           'ced': 1262,
#           '`': 8837,
#           '``': 17674,
#           'o': 42363,
#           'no': 4402,
#           'ce': 10953,
#           'nce': 5971,
#           "'": 10455,
#           "''": 17639,
#           'at': 25410,
#           'hat': 12692,
#           'ny': 3437,
#           'any': 2793,
#           'es': 22408,
#           'ies': 3708,
#           'k': 9215,
#           'ok': 1258,
#           'ook': 1230,
#           'ace': 2015,
#           '.': 152999,
#           'r': 58212,
#           'er': 28751,
#           'her': 8192,
#           'in': 47011,
#           'end': 1151,
#           'ts': 10808,
#           'nts': 3081,
#           'ity': 4010,
#           've': 10557,
#           'ive': 3826,
#           'ee': 2581,
#           'tee': 202,
#           ',': 175002,
#           'h': 26400,
#           'ch': 9265,
#           'ich': 3733,
#           'ad': 7515,
#           'had': 5134,
#           'l': 31996,
#           'll': 11458,
#           'all': 4992,
#           'ge': 4626,
#           'rge': 749,
#           'ves': 1456,
#           'se': 10380,
#           'ise': 829,
#           'ks': 1509,
#           'nks': 246,
#           'a': 74912,
#           'ta': 525,
#           'nta': 75,
#           'or': 22044,
#           'for': 9496,
#           'ner': 853,
#           'as': 28025,
#           'was': 9815,
#           'ted': 8520,
#           'ber': 1246,
#           'm': 16947,
#           'rm': 1289,
#           'erm': 136,
#           'en': 14705,
#           'een': 3955,
#           'ged': 977,
#           'by': 10922,
#           'ior': 418,
#           'rt': 3281,
#           'urt': 319,
#           'dge': 566,
#           'od': 2551,
#           'ood': 1743,
#           'ye': 189,
#           'pye': 1,
#           'to': 54483,
#           'te': 7147,
#           'ate': 4063,
#           'rts': 833,
#           'le': 11091,
#           'ble': 3817,
#           'ht': 4406,
#           'ght': 4391,
#           'won': 69,
#           'van': 70,
#           'len': 168,
#           'r.': 1280,
#           'jr.': 75,
#           'ly': 16395,
#           'nly': 2222,
#           'ul': 1111,
#           'ful': 988,
#           'uch': 2353,
#           'ved': 1800,
#           'g': 31294,
#           'ng': 30034,
#           'ing': 27283,
#           'ead': 1489,
#           'st': 12426,
#           'est': 2601,
#           'rs': 8633,
#           'ers': 5237,
#           'ze': 658,
#           'ize': 516,
#           'is': 33768,
#           'his': 12151,
#           'it': 19457,
#           'did': 1071,
#           'ind': 1490,
#           'ws': 955,
#           'aws': 143,
#           're': 21829,
#           'are': 5343,
#           'ded': 2519,
#           'ten': 940,
#           'us': 4883,
#           'ous': 2276,
#           'ors': 1130,
#           'ct': 3066,
#           'act': 1104,
#           'ave': 4759,
#           'ese': 1759,
#           'ied': 1682,
#           'sed': 3192,
#           'em': 3048,
#           'hem': 1796,
#           'cs': 689,
#           'ics': 638,
#           'ong': 1984,
#           'ell': 1846,
#           'w': 9115,
#           'ow': 4877,
#           'low': 894,
#           'lly': 3511,
#           'ces': 1975,
#           'ure': 2878,
#           'th': 11870,
#           'oth': 871,
#           'ger': 1065,
#           'ver': 3942,
#           'wo': 1430,
#           'two': 1430,
#           'ld': 9017,
#           'uld': 5210,
#           'be': 13068,
#           'ned': 3615,
#           'eve': 310,
#           'ter': 5704,
#           'cy': 1007,
#           'ncy': 445,
#           'uce': 211,
#           'ost': 2210,
#           'al': 14121,
#           'cal': 2662,
#           'el': 1920,
#           'nel': 210,
#           'lt': 1235,
#           'ult': 507,
#           'ke': 3858,
#           'ake': 1783,
#           'ps': 1459,
#           'eps': 162,
#           'dy': 1976,
#           'edy': 262,
#           'lem': 363,
#           'ile': 1338,
#           'tle': 1400,
#           'aw': 872,
#           'law': 322,
#           'so': 5118,
#           'lso': 1073,
#           'xt': 493,
#           'ext': 493,
#           'de': 4583,
#           'ide': 1856,
#           'ds': 4135,
#           'nds': 1681,
#           'et': 4785,
#           'set': 565,
#           'rly': 1222,
#           'may': 1408,
#           'pe': 1087,
#           'ipe': 61,
#           "t's": 1001,
#           'ral': 2193,
#           'ild': 386,
#           'mes': 1342,
#           'ne': 8075,
#           'one': 4984,
#           'jor': 250,
#           'ms': 2389,
#           'ems': 841,
#           'am': 1810,
#           'ram': 452,
#           'ut': 10052,
#           'but': 4401,
#           'has': 2439,
#           'fit': 187,
#           'ute': 464,
#           'gh': 2942,
#           'ugh': 2374,
#           'ith': 7550,
#           'ey': 5030,
#           'ney': 508,
#           'hey': 3645,
#           'ur': 3103,
#           'our': 2867,
#           'ss': 5510,
#           'ess': 3842,
#           'we': 5345,
#           'eel': 352,
#           'me': 10573,
#           'ome': 3588,
#           'do': 2863,
#           'ill': 3687,
#           'ue': 1799,
#           'nue': 191,
#           'den': 456,
#           "y's": 575,
#           'der': 2324,
#           'ire': 850,
#           'its': 2411,
#           'ns': 7893,
#           'ans': 1278,
#           'ees': 524,
#           'rds': 962,
#           'und': 1986,
#           'nto': 1910,
#           'res': 1212,
#           'ons': 4794,
#           'ar': 4754,
#           'bar': 92,
#           'im': 3036,
#           'rim': 79,
#           'ens': 435,
#           'rve': 290,
#           'ect': 1440,
#           'om': 5696,
#           'rom': 4380,
#           'due': 168,
#           'sts': 1249,
#           'sms': 65,
#           'ew': 3326,
#           'new': 2042,
#           'lar': 908,
#           'ort': 1208,
#           'hen': 3907,
#           'kes': 476,
#           'n.': 213,
#           'an.': 23,
#           '1': 2168,
#           'ot': 6333,
#           'not': 4880,
#           'ere': 8198,
#           'c': 5324,
#           'ic': 4612,
#           'dic': 35,
#           'ose': 2133,
#           'sk': 390,
#           'ask': 203,
#           'il': 1642,
#           'ail': 397,
#           ':': 5385,
#           '(': 7305,
#           ')': 7416,
#           'nal': 2479,
#           'yed': 534,
#           'tor': 1121,
#           'rn': 1872,
#           'ern': 887,
#           'uty': 156,
#           '2': 1871,
#           'rk': 1765,
#           'ork': 1187,
#           'ls': 2947,
#           'als': 960,
#           'ass': 722,
#           'mit': 235,
#           'ir': 3547,
#           'air': 729,
#           'lan': 258,
#           'yes': 579,
#           'ice': 2059,
#           'x': 1317,
#           'ax': 300,
#           'tax': 207,
#           "r's": 700,
#           'tta': 69,
#           'son': 1556,
#           'rms': 591,
#           'ady': 589,
#           'tal': 1024,
#           'lth': 142,
#           'yor': 48,
#           'iam': 182,
#           'b.': 200,
#           'eld': 696,
#           'led': 2845,
#           'uit': 164,
#           'rce': 468,
#           'fe': 1194,
#           'ife': 1057,
#           'rl': 316,
#           'arl': 73,
#           'ams': 391,
#           'lty': 267,
#           'ple': 1767,
#           'g.': 232,
#           'ug.': 25,
#           '3': 1242,
#           '13': 126,
#           '913': 12,
#           'rry': 414,
#           's.': 1025,
#           'rs.': 548,
#           'j.': 244,
#           'm.': 283,
#           'fin': 24,
#           'ys': 1806,
#           'eys': 96,
#           'rty': 624,
#           'eed': 1021,
#           'pon': 555,
#           'age': 2101,
#           '71': 31,
#           "e's": 918,
#           '4': 1020,
#           '74': 22,
#           'rth': 752,
#           'ka': 94,
#           'ika': 9,
#           'a.': 310,
#           'la.': 28,
#           'man': 2603,
#           'ore': 4102,
#           'han': 1851,
#           'ear': 2040,
#           '7': 638,
#           '37': 43,
#           '637': 2,
#           'e.': 234,
#           'ham': 109,
#           'd.': 177,
#           'rd.': 3,
#           'j': 148,
#           'aj': 237,
#           'nry': 94,
#           'l.': 148,
#           'ef': 424,
#           'ief': 370,
#           'ude': 430,
#           '937': 10,
#           'eer': 268,
#           'oes': 772,
#           'ck': 3360,
#           'ack': 1742,
#           'cil': 142,
#           '23': 108,
#           '923': 7,
#           'ho': 2286,
#           'who': 2252,
#           'ame': 2227,
#           't.': 333,
#           'pt.': 47,
#           'un': 683,
#           'run': 250,
#           'ia': 998,
#           'gia': 58,
#           '62': 51,
#           '962': 35,
#           'p': 6309,
#           'op': 785,
#           'top': 358,
#           'ial': 2372,
#           'ert': 379,
#           'gop': 13,
#           'lue': 372,
#           'tic': 1530,
#           'ses': 1905,
#           'w.': 174,
#           'sey': 86,
#           'sm': 777,
#           'asm': 48,
#           'up': 4404,
#           '8': 730,
#           'ah': 177,
#           'nah': 12,
#           'wly': 150,
#           'xas': 69,
#           'en.': 53,
#           'hn': 392,
#           'ohn': 374,
#           'wer': 869,
#           'red': 4441,
#           'ker': 411,
#           'nor': 460,
#           'out': 4782,
#           'cts': 990,
#           'ain': 2283,
#           'ite': 1431,
#           'ote': 515,
#           'wd': 64,
#           'owd': 53,
#           'ked': 2156,
#           'ait': 140,
#           '-': 3718,
#           '--': 6864,
#           'dle': 320,
#           'ays': 1467,
#           'rst': 1496,
#           'ust': 2201,
#           'ken': 570,
#           'per': 1048,
#           'ach': 1343,
#           'gn': 517,
#           'ign': 517,
#           'wed': 682,
#           'tes': 1901,
#           'lot': 262,
#           'old': 1861,
#           'nit': 117,
#           'tem': 509,
#           'orm': 639,
#           'sam': 95,
#           'way': 1685,
#           'lic': 678,
#           'lt.': 8,
#           'v.': 136,
#           'ov.': 41,
#           "d's": 325,
#           "l's": 198,
#           'ime': 1921,
#           'b': 1225,
#           'ob': 331,
#           'rob': 20,
#           'rd': 3399,
#           'ord': 749,
#           'lle': 183,
#           'ant': 2252,
#           'ree': 1207,
#           'ars': 1656,
#           'yrd': 10,
#           '61': 163,
#           '961': 135,
#           'ond': 724,
#           'tly': 1942,
#           'oon': 491,
#           'ove': 993,
#           'udy': 270,
#           'ban': 106,
#           'eas': 487,
#           'ine': 2069,
#           'ade': 1611,
#           'sit': 202,
#           'ard': 2320,
#           'ely': 2358,
#           '0': 2088,
#           '00': 807,
#           '100': 97,
#           'sue': 238,
#           'ier': 491,
#           'ery': 1925,
#           '30': 290,
#           '$30': 2,
#           'go': 1733,
#           'dly': 687,
#           'les': 1897,
#           'gin': 205,
#           'let': 563,
#           'ily': 1063,
#           '$3': 6,
#           '$4': 10,
#           'ads': 264,
#           'oad': 476,
#           'ued': 339,
#           'nes': 983,
#           'ff': 1049,
#           'off': 690,
#           '58': 116,
#           '958': 94,
#           'nst': 635,
#           '50': 247,
#           '$50': 7,
#           'vin': 55,
#           'yet': 420,
#           'ley': 363,
#           'p.': 180,
#           'ep.': 13,
#           'fer': 296,
#           'use': 2463,
#           'lf': 1701,
#           'elf': 1295,
#           '10': 363,
#           '$10': 7,
#           'ase': 1136,
#           'nse': 782,
#           'rch': 790,
#           'ie': 854,
#           'kie': 40,
#           'can': 2547,
#           'ven': 1885,
#           'ils': 262,
#           'ek': 503,
#           'eek': 471,
#           'ege': 299,
#           '31': 95,
#           '-31': 1,
#           '5': 1090,
#           '-5': 12,
#           '9-5': 1,
#           'ast': 2054,
#           'pay': 179,
#           'ran': 197,
#           'ac': 84,
#           'mac': 5,
#           'rse': 938,
#           '3th': 6,
#           'ike': 1674,
#           'see': 806,
#           'men': 1321,
#           'him': 2627,
#           'tt': 203,
#           'itt': 26,
#           'hot': 268,
#           'sy': 404,
#           'rsy': 26,
#           'ler': 509,
#           'ol': 1277,
#           'ool': 789,
#           'put': 498,
#           'i': 16413,
#           'saw': 365,
#           'vis': 51,
#           'ix': 328,
#           'lix': 32,
#           'sh': 1673,
#           'ush': 173,
#           'pal': 143,
#           '9': 533,
#           '19': 81,
#           '119': 1,
#           'got': 501,
#           '02': 13,
#           '402': 1,
#           'rey': 69,
#           'med': 1334,
#           'tol': 55,
#           'lls': 688,
#           'tom': 212,
#           "'t": 2102,
#           "n't": 2100,
#           'rop': 91,
#           'uor': 47,
#           'bit': 192,
#           'iet': 260,
#           'ats': 301,
#           'mer': 563,
#           'ath': 546,
#           '18': 127,
#           'oo': 867,
#           'too': 835,
#           'gun': 185,
#           'iff': 85,
#           'bb': 34,
#           'abb': 5,
#           'eal': 697,
#           'tin': 180,
#           'val': 315,
#           'iel': 33,
#           'wn': 2996,
#           'own': 2859,
#           'bly': 847,
#           'ft': 898,
#           'eft': 496,
#           'bt': 127,
#           'ubt': 114,
#           '17': 106,
#           'lp': 345,
#           'elp': 330,
#           'cit': 59,
#           '63': 25,
#           'eat': 1219,
#           'oks': 219,
#           'nk': 1094,
#           'ank': 321,
#           'cks': 364,
#           'rer': 157,
#           'now': 2060,
#           'wey': 8,
#           'yer': 225,
#           'eir': 2679,
#           'ual': 1114,
#           'if': 4407,
#           'u': 3739,
#           'ou': 3326,
#           'you': 3290,
#           'oy': 504,
#           'roy': 96,
#           'my': 3129,
#           'omy': 140,
#           'hes': 860,
#           'sor': 129,
#           'unt': 469,
#           'ift': 169,
#           "s'": 418,
#           "rs'": 123,
#           'ets': 715,
#           'ott': 42,
#           'gen': 134,
#           'ox': 170,
#           'cox': 9,
#           'sly': 633,
#           'las': 192,
#           'ols': 335,
#           'af': 2035,
#           'eaf': 34,
#           'ish': 1109,
#           '000': 402,
#           'ren': 454,
#           '6': 703,
#           'get': 944,
#           'ris': 218,
#           'xar': 1,
#           'aso': 11,
#           '500': 64,
#           'gs': 1821,
#           'ngs': 1499,
#           '60': 304,
#           '460': 2,
#           'lay': 532,
#           'bed': 528,
#           'ea': 737,
#           'tea': 30,
#           '82': 13,
#           '182': 1,
#           'els': 505,
#           'ps.': 2,
#           'oe': 146,
#           'joe': 55,
#           'lks': 63,
#           'hy': 881,
#           'why': 404,
#           "'re": 283,
#           'ro': 369,
#           'pro': 17,
#           'con': 43,
#           "'m": 269,
#           "i'm": 269,
#           'san': 159,
#           'io': 346,
#           'nio': 10,
#           'acy': 219,
#           'sal': 169,
#           'kly': 153,
#           'ped': 1223,
#           'dar': 52,
#           'ont': 343,
#           'ict': 253,
#           'ird': 260,
#           'mar': 15,
#           'z': 303,
#           'tz': 70,
#           'rtz': 10,
#           'ulf': 39,
#           'pt': 907,
#           'ept': 626,
#           'fts': 51,
#           'uis': 86,
#           'mp': 245,
#           'ump': 80,
#           'ba': 105,
#           'aba': 4,
#           'oup': 427,
#           'xes': 110,
#           'urn': 508,
#           'zed': 773,
#           'lus': 144,
#           'gue': 257,
#           'kin': 122,
#           'fee': 98,
#           '12': 229,
#           '$12': 1,
#           'gas': 108,
#           'wen': 43,
#           'irs': 275,
#           'mby': 3,
#           'iew': 283,
#           'eme': 205,
#           'oll': 123,
#           '81': 20,
#           '65': 56,
#           'um': 832,
#           'dum': 9,
#           'ril': 83,
#           '.s.': 171,
#           'ole': 579,
#           'dea': 197,
#           'xan': 5,
#           'eb.': 20,
#           '22': 114,
#           'eds': 358,
#           "as'": 12,
#           'ig': 435,
#           'big': 360,
#           '250': 17,
#           '14': 144,
#           '114': 4,
#           'mum': 164,
#           'oan': 82,
#           'elt': 433,
#           "n's": 924,
#           'nan': 27,
#           'mas': 158,
#           'gio': 18,
#           'la': 389,
#           'za': 47,
#           'rza': 1,
#           'f.': 156,
#           'ins': 715,
#           'hur': 56,
#           'oor': 627,
#           'nut': 49,
#           'ods': 399,
#           'c.': 378,
#           'ory': 1227,
#           '24': 119,
#           'urs': 330,
#           'igh': 535,
#           'mal': 399,
#           'dit': 75,
#           'try': 906,
#           '150': 15,
#           'sp.': 2,
#           'dr.': 193,
#           'ark': 507,
#           'lds': 192,
#           'ma': 388,
#           'oma': 24,
#           '&': 489,
#           'lor': 239,
#           'ode': 343,
#           'tts': 58,
#           'gy': 447,
#           'ogy': 254,
#           'eam': 303,
#           'rps': 110,
#           'rmy': 143,
#           '-62': 2,
#           'o.': 180,
#           'bon': 65,
#           'dc': 27,
#           'adc': 8,
#           'irm': 140,
#           'nge': 754,
#           'lve': 131,
#           'hly': 239,
#           '.4': 20,
#           '4.4': 1,
#           'gil': 4,
#           'rie': 76,
#           'co.': 48,
#           'ume': 250,
#           'ups': 175,
#           'ale': 422,
#           'ilt': 159,
#           'ows': 542,
#           'sel': 56,
#           'rel': 67,
#           'six': 234,
#           'oom': 572,
#           'gly': 362,
#           'nch': 444,
#           'ean': 529,
#           '?': 14079,
#           'rue': 243,
#           'uly': 143,
#           'hed': 1756,
#           'lin': 228,
#           'sis': 640,
#           'row': 363,
#           'dio': 158,
#           'ape': 241,
#           'cod': 6,
#           'ids': 173,
#           'hom': 155,
#           'nis': 38,
#           'ss.': 18,
#           'rre': 38,
#           'say': 530,
#           'ru': 30,
#           'hru': 21,
#           'aff': 123,
#           'eet': 832,
#           'rns': 261,
#           'gal': 110,
#           'hts': 341,
#           "ns'": 41,
#           'mpt': 136,
#           '77': 18,
#           '677': 2,
#           '33': 38,
#           '133': 5,
#           'nas': 36,
#           '200': 51,
#           'rg': 149,
#           'erg': 67,
#           'ges': 923,
#           '8th': 22,
#           'nct': 79,
#           '3d': 7,
#           '23d': 5,
#           'tho': 2,
#           'st.': 168,
#           '35': 75,
#           '33d': 1,
#           '4th': 20,
#           '2d': 9,
#           '42d': 1,
#           '1st': 9,
#           '9th': 22,
#           'ims': 133,
#           'aed': 1,
#           'iss': 311,
#           'eby': 64,
#           '70': 78,
#           '.2': 32,
#           '4.2': 8,
#           'ips': 304,
#           '20': 242,
#           '$37': 3,
#           '800': 25,
#           '.5': 54,
#           '6.5': 1,
#           '25': 206,
#           '.25': 3,
#           '7.5': 5,
#           '963': 11,
#           'vy': 195,
#           'evy': 11,
#           '1.5': 13,
#           '750': 9,
#           'ull': 366,
#           '90': 37,
#           '80': 68,
#           '180': 8,
#           '300': 39,
#           'ula': 98,
#           'art': 1266,
#           'nic': 351,
#           '$20': 6,
#           '40': 126,
#           '240': 2,
#           'tay': 113,
#           'cut': 227,
#           'dom': 296,
#           '92': 25,
#           '47': 43,
#           'ung': 598,
#           'ip': 1006,
#           'hip': 707,
#           '.1': 37,
#           '5.1': 2,
#           '21': 117,
#           '66': 17,
#           '966': 4,
#           '700': 18,
#           'rea': 345,
#           'sum': 51,
#           'au': 116,
#           'eau': 86,
#           'sks': 70,
#           'how': 1224,
#           '540': 3,
#           'sen': 174,
#           'll.': 13,
#           'eck': 239,
#           'nd.': 3,
#           'x.': 7,
#           'ex.': 7,
#           'hty': 59,
#           '11': 153,
#           'gro': 119,
#           'net': 107,
#           'ule': 137,
#           'yne': 70,
#           're.': 4,
#           '53': 52,
#           '953': 27,
#           'lo': 180,
#           'slo': 5,
#           'aty': 36,
#           'ep': 743,
#           'tep': 156,
#           'met': 145,
#           'dor': 77,
#           'ist': 1179,
#           'ash': 180,
#           'ca': 320,
#           'ica': 281,
#           'few': 601,
#           'eks': 173,
#           'ago': 353,
#           'lk': 403,
#           'alk': 281,
#           'ato': 87,
#           'ola': 34,
#           'icy': 243,
#           'rsh': 19,
#           'sic': 441,
#           'oc': 49,
#           'hoc': 3,
#           'da': 294,
#           'ada': 62,
#           'mic': 531,
#           'ser': 188,
#           'mat': 19,
#           "k's": 109,
#           'dd': 149,
#           'add': 89,
#           'mr.': 844,
#           'bal': 49,
#           'mly': 105,
#           'xed': 186,
#           'arn': 162,
#           'ots': 235,
#           'ech': 78,
#           'hs': 428,
#           'ths': 341,
#           "es'": 80,
#           "o's": 131,
#           'aps': 370,
#           'obe': 45,
#           'tus': 170,
#           'hin': 492,
#           'hod': 146,
#           'va': 111,
#           'eva': 26,
#           'os': 353,
#           'aos': 82,
#           'pts': 102,
#           'ism': 725,
#           'uth': 641,
#           'nam': 17,
#           'pes': 271,
#           'ao': 37,
#           'lao': 17,
#           'cto': 7,
#           'rol': 293,
#           'rld': 797,
#           'xon': 71,
#           'oit': 33,
#           'lup': 1,
#           'uba': 50,
#           'ply': 490,
#           'ky': 268,
#           'cky': 74,
#           'eis': 3,
#           'nte': 38,
#           'tro': 48,
#           'loc': 15,
#           ';': 16698,
#           'ian': 915,
#           'fic': 335,
#           'til': 463,
#           'co': 222,
#           'sco': 65,
#           'iod': 265,
#           'pin': 38,
#           'hus': 322,
#           'far': 438,
#           'eze': 47,
#           'het': 27,
#           ...})

# %%
a=["hello","how","are","you"]

# %%
suffix_fdis = FreqDist()

for word in a:
    
    word = word.lower()
    suffix_fdis[word[-1:]] += 1
    suffix_fdis[word[-2:]] += 1
    suffix_fdis[word[-3:]] += 1
    
suffix_fdis
# Out:
# FreqDist({'are': 1,
#           'e': 1,
#           'how': 1,
#           'llo': 1,
#           'lo': 1,
#           'o': 1,
#           'ou': 1,
#           'ow': 1,
#           're': 1,
#           'u': 1,
#           'w': 1,
#           'you': 1})

# %%
common_suffixes = [suffix for (suffix, count) in suffix_fdist.most_common(100)]
common_suffixes[:10]
# Out:
# ['e', ',', '.', 's', 'd', 't', 'he', 'n', 'a', 'of']

# %%
def pos_features(word):
    features = {}
    for suffix in common_suffixes:
        features['endswith({})'.format(suffix)] = word.lower().endswith(suffix)
    return features

pos_features('test')
# Out:
# {"endswith('')": False,
#  "endswith(')": False,
#  "endswith('s)": False,
#  'endswith(()': False,
#  'endswith())': False,
#  'endswith(,)': False,
#  'endswith(--)': False,
#  'endswith(.)': False,
#  'endswith(:)': False,
#  'endswith(;)': False,
#  'endswith(?)': False,
#  'endswith(`)': False,
#  'endswith(``)': False,
#  'endswith(a)': False,
#  'endswith(ad)': False,
#  'endswith(al)': False,
#  'endswith(an)': False,
#  'endswith(and)': False,
#  'endswith(are)': False,
#  'endswith(as)': False,
#  'endswith(at)': False,
#  'endswith(ay)': False,
#  'endswith(be)': False,
#  'endswith(by)': False,
#  'endswith(c)': False,
#  'endswith(ce)': False,
#  'endswith(ch)': False,
#  'endswith(d)': False,
#  'endswith(e)': False,
#  'endswith(ed)': False,
#  'endswith(en)': False,
#  'endswith(ent)': False,
#  'endswith(er)': False,
#  'endswith(ere)': False,
#  'endswith(ers)': False,
#  'endswith(es)': False,
#  'endswith(ey)': False,
#  'endswith(f)': False,
#  'endswith(for)': False,
#  'endswith(g)': False,
#  'endswith(h)': False,
#  'endswith(had)': False,
#  'endswith(hat)': False,
#  'endswith(he)': False,
#  'endswith(her)': False,
#  'endswith(his)': False,
#  'endswith(i)': False,
#  'endswith(in)': False,
#  'endswith(ing)': False,
#  'endswith(ion)': False,
#  'endswith(is)': False,
#  'endswith(it)': False,
#  'endswith(ith)': False,
#  'endswith(k)': False,
#  'endswith(l)': False,
#  'endswith(ld)': False,
#  'endswith(le)': False,
#  'endswith(ll)': False,
#  'endswith(ly)': False,
#  'endswith(m)': False,
#  'endswith(me)': False,
#  'endswith(n)': False,
#  'endswith(nce)': False,
#  'endswith(nd)': False,
#  'endswith(ne)': False,
#  'endswith(ng)': False,
#  'endswith(ns)': False,
#  'endswith(nt)': False,
#  'endswith(o)': False,
#  'endswith(of)': False,
#  'endswith(om)': False,
#  'endswith(on)': False,
#  'endswith(or)': False,
#  'endswith(ot)': False,
#  'endswith(p)': False,
#  'endswith(r)': False,
#  'endswith(re)': False,
#  'endswith(rs)': False,
#  'endswith(ry)': False,
#  'endswith(s)': False,
#  'endswith(se)': False,
#  'endswith(so)': False,
#  'endswith(ss)': False,
#  'endswith(st)': True,
#  'endswith(t)': True,
#  'endswith(te)': False,
#  'endswith(ted)': False,
#  'endswith(ter)': False,
#  'endswith(th)': False,
#  'endswith(the)': False,
#  'endswith(to)': False,
#  'endswith(ts)': False,
#  'endswith(ty)': False,
#  'endswith(uld)': False,
#  'endswith(ut)': False,
#  'endswith(ve)': False,
#  'endswith(w)': False,
#  'endswith(was)': False,
#  'endswith(we)': False,
#  'endswith(y)': False}

# %%
tagged_words = brown.tagged_words(categories='news')
featuresets = [(pos_features(n), g) for (n,g) in tagged_words]
featuresets[0]
# Out:
# ({"endswith('')": False,
#   "endswith(')": False,
#   "endswith('s)": False,
#   'endswith(()': False,
#   'endswith())': False,
#   'endswith(,)': False,
#   'endswith(--)': False,
#   'endswith(.)': False,
#   'endswith(:)': False,
#   'endswith(;)': False,
#   'endswith(?)': False,
#   'endswith(`)': False,
#   'endswith(``)': False,
#   'endswith(a)': False,
#   'endswith(ad)': False,
#   'endswith(al)': False,
#   'endswith(an)': False,
#   'endswith(and)': False,
#   'endswith(are)': False,
#   'endswith(as)': False,
#   'endswith(at)': False,
#   'endswith(ay)': False,
#   'endswith(be)': False,
#   'endswith(by)': False,
#   'endswith(c)': False,
#   'endswith(ce)': False,
#   'endswith(ch)': False,
#   'endswith(d)': False,
#   'endswith(e)': True,
#   'endswith(ed)': False,
#   'endswith(en)': False,
#   'endswith(ent)': False,
#   'endswith(er)': False,
#   'endswith(ere)': False,
#   'endswith(ers)': False,
#   'endswith(es)': False,
#   'endswith(ey)': False,
#   'endswith(f)': False,
#   'endswith(for)': False,
#   'endswith(g)': False,
#   'endswith(h)': False,
#   'endswith(had)': False,
#   'endswith(hat)': False,
#   'endswith(he)': True,
#   'endswith(her)': False,
#   'endswith(his)': False,
#   'endswith(i)': False,
#   'endswith(in)': False,
#   'endswith(ing)': False,
#   'endswith(ion)': False,
#   'endswith(is)': False,
#   'endswith(it)': False,
#   'endswith(ith)': False,
#   'endswith(k)': False,
#   'endswith(l)': False,
#   'endswith(ld)': False,
#   'endswith(le)': False,
#   'endswith(ll)': False,
#   'endswith(ly)': False,
#   'endswith(m)': False,
#   'endswith(me)': False,
#   'endswith(n)': False,
#   'endswith(nce)': False,
#   'endswith(nd)': False,
#   'endswith(ne)': False,
#   'endswith(ng)': False,
#   'endswith(ns)': False,
#   'endswith(nt)': False,
#   'endswith(o)': False,
#   'endswith(of)': False,
#   'endswith(om)': False,
#   'endswith(on)': False,
#   'endswith(or)': False,
#   'endswith(ot)': False,
#   'endswith(p)': False,
#   'endswith(r)': False,
#   'endswith(re)': False,
#   'endswith(rs)': False,
#   'endswith(ry)': False,
#   'endswith(s)': False,
#   'endswith(se)': False,
#   'endswith(so)': False,
#   'endswith(ss)': False,
#   'endswith(st)': False,
#   'endswith(t)': False,
#   'endswith(te)': False,
#   'endswith(ted)': False,
#   'endswith(ter)': False,
#   'endswith(th)': False,
#   'endswith(the)': True,
#   'endswith(to)': False,
#   'endswith(ts)': False,
#   'endswith(ty)': False,
#   'endswith(uld)': False,
#   'endswith(ut)': False,
#   'endswith(ve)': False,
#   'endswith(w)': False,
#   'endswith(was)': False,
#   'endswith(we)': False,
#   'endswith(y)': False},
#  'AT')

# %%
for (n,g) in tagged_words:
  print(n,g)

# %%
from nltk import DecisionTreeClassifier
from nltk.classify import accuracy

cutoff = int(len(featuresets) * 0.1)
train_set, test_set = featuresets[cutoff:], featuresets[:cutoff]

# %%
classifier = DecisionTreeClassifier.train(train_set) # NLTK is a teaching toolkit which is not really optimized for speed. Therefore, this may take forever. For speed, use scikit-learn for the classifiers.
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-29dbebabfea6> in <module>()
#       1
# ----> 2 classifier = DecisionTreeClassifier.train(train_set) # NLTK is a teaching toolkit which is not really optimized for speed. Therefore, this may take forever. For speed, use scikit-learn for the classifiers.
#
# /usr/local/lib/python3.6/dist-packages/nltk/classify/decisiontree.py in train(labeled_featuresets, entropy_cutoff, depth_cutoff, support_cutoff, binary, feature_values, verbose)
#     152         if not binary:
#     153             tree = DecisionTreeClassifier.best_stump(
# --> 154                 feature_names, labeled_featuresets, verbose)
#     155         else:
#     156             tree = DecisionTreeClassifier.best_binary_stump(
#
# /usr/local/lib/python3.6/dist-packages/nltk/classify/decisiontree.py in best_stump(feature_names, labeled_featuresets, verbose)
#     219         best_error = best_stump.error(labeled_featuresets)
#     220         for fname in feature_names:
# --> 221             stump = DecisionTreeClassifier.stump(fname, labeled_featuresets)
#     222             stump_error = stump.error(labeled_featuresets)
#     223             if stump_error < best_error:
#
# /usr/local/lib/python3.6/dist-packages/nltk/classify/decisiontree.py in stump(feature_name, labeled_featuresets)
#     179         for featureset, label in labeled_featuresets:
#     180             feature_value = featureset.get(feature_name)
# --> 181             freqs[feature_value][label] += 1
#     182
#     183         decisions = dict((val, DecisionTreeClassifier(freqs[val].max()))
#
# /usr/local/lib/python3.6/dist-packages/nltk/probability.py in __setitem__(self, key, val)
#     125         return self._N
#     126
# --> 127     def __setitem__(self, key, val):
#     128         """
#     129         Override ``Counter.__setitem__()`` to invalidate the cached N
#
# KeyboardInterrupt:

# %%
accuracy(classifier, test_set)
classifier.classify(pos_features('cats'))

classifier.pseudocode(depth=4)
